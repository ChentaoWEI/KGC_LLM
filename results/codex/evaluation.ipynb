# %%
import pandas as pd
import numpy as np
import ast
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.preprocessing import LabelEncoder

# %%
import sys
import os
notebook_dir = os.getcwd()
codex_dir = os.path.join(notebook_dir, '..','..','Codex','codex')
sys.path.append(codex_dir)
from codex import Codex
codex = Codex(size='s', code='en')
all_relations = codex.split('train')['relation'].unique()
all_relations = [codex.relation_label(relation) for relation in all_relations]
all_relations.append('Relationship is ambiguous')
all_relations = [relation.lower() for relation in all_relations]

# %%
df = pd.read_csv('zero_cot_multi_relation_non_ambiguous/result.csv')
df.loc[df['Label'] == 0, 'true_relation'] = 'relationship is ambiguous'

# %%
df.verification = df.verification.apply(lambda x: ast.literal_eval(x))
df.pred_relation = df.pred_relation.apply(lambda x: ast.literal_eval(x))

# %%
import re
pred_verifications = []
for ind, row in df.iterrows():
    result = []
    for i, ver in enumerate(row['verification']):
        if ver == 'relationship is ambiguous':
            result.append('relationship is ambiguous')
        else:
            match = re.search(r'^\w+', ver)
            if match:
                first_word = match.group()
                if str.lower(first_word) not in ['true','false']:
                    print(row)
                    break
                else:
                    result.append(str.lower(first_word))
            else:
                print(f"faliure in row {ind}")
    pred_verifications.append(result)
df['pred_verification'] = pred_verifications
# Out:
# head                                                       Thomas Mann
# relation                                                    occupation
# tail                                                          essayist
# Label                                                                1
# head_id                                                         Q37030
# relation_id                                                       P106
# tail_id                                                      Q11774202
# prompt               What is the relationship between 'Thomas Mann'...
# response             Reasoning process: Thomas Mann is a notable Ge...
# pred_relation                                             [occupation]
# true_relation                                               occupation
# verification         [Solution: False. Reason: Thomas Mann was a re...
# pred_verification                                        ['not found']
# Name: 676, dtype: object

# %%
def process_verification(row):
    result = []
    for i, ver in enumerate(row['pred_verification']):
        if ver == 'relationship is ambiguous':
            result.append('relationship is ambiguous')
        else:
            if ver == 'true':
                result.append(row['pred_relation'][i])
    if not result:
        result.append('relationship is ambiguous')
    row['final_pred'] = result
    return row['final_pred']

df['final_pred'] = None
df['final_pred'] = df.apply(process_verification, axis=1)
df
# Out:
#                     head                              relation  \
# 0     Herbert Grönemeyer                country of citizenship
# 1    "Weird Al" Yankovic                          record label
# 2    Walt Disney Records                            founded by
# 3        Johnny Hallyday                country of citizenship
# 4                Madonna  languages spoken, written, or signed
# ..                   ...                                   ...
# 995     Chord Overstreet                            occupation
# 996    Eleanor Roosevelt                             residence
# 997    Harry Connick Jr.                                 genre
# 998     Saint Petersburg                           named after
# 999            Jan Rubes                country of citizenship
#
#                  tail  Label  head_id relation_id  tail_id  \
# 0           Australia      0  Q275247         P27     Q408
# 1    Atlantic Records      0    Q8349        P264  Q202440
# 2          Debby Ryan      0   Q54860        P112  Q204005
# 3         Switzerland      0  Q212015         P27      Q39
# 4              French      1    Q1744       P1412     Q150
# ..                ...    ...      ...         ...      ...
# 995            singer      1   Q53714        P106  Q177220
# 996  Washington, D.C.      1   Q83396        P551      Q61
# 997  rhythm and blues      0  Q313755        P136   Q45981
# 998    Vladimir Lenin      1     Q656        P138    Q1394
# 999            Canada      1  Q187884         P27      Q16
#
#                                                 prompt  \
# 0    What is the relationship between 'Herbert Grön...
# 1    What is the relationship between '"Weird Al" Y...
# 2    What is the relationship between 'Walt Disney ...
# 3    What is the relationship between 'Johnny Hally...
# 4    What is the relationship between 'Madonna' and...
# ..                                                 ...
# 995  What is the relationship between 'Chord Overst...
# 996  What is the relationship between 'Eleanor Roos...
# 997  What is the relationship between 'Harry Connic...
# 998  What is the relationship between 'Saint Peters...
# 999  What is the relationship between 'Jan Rubes' a...
#
#                                               response  \
# 0    Reasoning process: Herbert Grönemeyer is a Ger...
# 1    Reasoning process: "Weird Al" Yankovic is a mu...
# 2    Reasoning process: Walt Disney Records is a re...
# 3    Reasoning process: Johnny Hallyday is a promin...
# 4    Reasoning process: Madonna is a singer who has...
# ..                                                 ...
# 995  Reasoning process: Chord Overstreet is an indi...
# 996  Reasoning process: Eleanor Roosevelt was a pro...
# 997  Reasoning process: Harry Connick Jr. is a musi...
# 998  Reasoning process: Saint Petersburg is a city ...
# 999  Reasoning process: Jan Rubes was a Czech-Canad...
#
#                                          pred_relation  \
# 0          [performed in, has toured in, performed in]
# 1                         [record label, record label]
# 2                                       [record label]
# 3                                          [residence]
# 4                                      [influenced by]
# ..                                                 ...
# 995                                       [occupation]
# 996                                        [residence]
# 997                                            [genre]
# 998                                   [place of birth]
# 999  [country of citizenship, residence, country of...
#
#                             true_relation  \
# 0               relationship is ambiguous
# 1               relationship is ambiguous
# 2               relationship is ambiguous
# 3               relationship is ambiguous
# 4    languages spoken, written, or signed
# ..                                    ...
# 995                            occupation
# 996                             residence
# 997             relationship is ambiguous
# 998                           named after
# 999                country of citizenship
#
#                                           verification     pred_verification  \
# 0    [False. Reason: Herbert Grönemeyer is a German...  [false, true, false]
# 1    [True. Reason: "Weird Al" Yankovic has been si...         [true, false]
# 2    [False. Reason: Walt Disney Records is a recor...               [false]
# 3    [False. Reason: Johnny Hallyday, the French si...               [false]
# 4    [False. Reason: Madonna is a pop singer known ...               [false]
# ..                                                 ...                   ...
# 995  [False. Reason: Chord Overstreet is an actor a...               [false]
# 996  [True. Reason: Eleanor Roosevelt lived in the ...                [true]
# 997  [False. Reason: Harry Connick Jr. is known for...               [false]
# 998  [True. Reason: Vladimir Lenin, the Russian rev...                [true]
# 999  [True. Reason: Jan Rubes was a Czech-born Cana...   [true, false, true]
#
#                                            final_pred
# 0                                     [has toured in]
# 1                                      [record label]
# 2                         [relationship is ambiguous]
# 3                         [relationship is ambiguous]
# 4                         [relationship is ambiguous]
# ..                                                ...
# 995                       [relationship is ambiguous]
# 996                                       [residence]
# 997                       [relationship is ambiguous]
# 998                                  [place of birth]
# 999  [country of citizenship, country of citizenship]
#
# [1000 rows x 14 columns]

# %% [markdown]
# <h3>Hit at 1</h3>

# %%
hit = 1
hit_at_1_first = 0
hit_at_1_second = 0
for index, row in df.iterrows():
    if len(row['pred_relation']) < hit:
        if row['true_relation'] in row['pred_relation']:
            hit_at_1_first += 1
    else:
        if row['true_relation'] in row['pred_relation'][:hit]:
            hit_at_1_first += 1

    if len(row['final_pred']) < hit:
        if row['true_relation'] in row['final_pred']:
            hit_at_1_second += 1
    else:
        if row['true_relation'] in row['final_pred'][:hit]:
            hit_at_1_second += 1
hit_at_1_first = hit_at_1_first/len(df)
hit_at_1_second = hit_at_1_second/len(df)
print(f"hit at {hit} ask first: {hit_at_1_first}")
print(f"hit at {hit} ask twice: {hit_at_1_second}")
# Out:
# hit at 1 ask first: 0.289
# hit at 1 ask twice: 0.588

# %% [markdown]
# <h3>The possibility of the right answer included in the prediction</h3>

# %%
included_first = 0
included_second = 0
for index, row in df.iterrows():
    if row['true_relation'] in row['pred_relation']:
        included_first += 1

    if row['true_relation'] in row['final_pred']:
        included_second += 1
        
included_first = included_first/len(df)
included_second = included_second/len(df)
print(f"true relation is included in the predictions, ask first: {included_first}")
print(f"true relation is included in the predictions, ask twice: {included_second}")
# Out:
# true relation is included in the predictions, ask first: 0.303
# true relation is included in the predictions, ask twice: 0.594

# %% [markdown]
# <h3>Negative sample correction rate</h3>

# %%
hit = 1
hit_at_1_first_neg= 0
hit_at_1_second_neg = 0
for index, row in df.iterrows():
    if row['true_relation'] != 'relationship is ambiguous':
        continue
    
    if len(row['pred_relation']) < hit:
        if row['true_relation'] in row['pred_relation']:
            hit_at_1_first += 1
    else:
        if row['true_relation'] in row['pred_relation'][:hit]:
            hit_at_1_first += 1

    if len(row['final_pred']) < hit:
        if row['true_relation'] in row['final_pred']:
            hit_at_1_second += 1
    else:
        if row['true_relation'] in row['final_pred'][:hit]:
            hit_at_1_second += 1
hit_at_1_first = hit_at_1_first/(len(df)/2)
hit_at_1_second = hit_at_1_second/(len(df)/2)
print(f"hit at {hit} ask first: {hit_at_1_first}")
print(f"hit at {hit} ask twice: {hit_at_1_second}")
# Out:
# hit at 1 ask first: 0.000578
# hit at 1 ask twice: 0.8411759999999999
